# %%
##---purpose of this script is to extract the large fires from the FOD based on the calculated large-fire size from the 2025 National FSim
import os
import geopandas as gpd
import rasterio as rio

# %%
#--- load in data sources
# fire occurrence
fod_gdb = r"C:\Users\Charlie\Desktop\ArcGIS\data\NatFSim\NatFSim2022\fire_occurrence\FPA_FOD_20221014.gdb"
fires = gpd.read_file(fod_gdb, layer="Fires")

# # PY 136 IDG
# PY136_path = r"C:\Users\Charlie\Desktop\ArcGIS\data\NatFSim\NatFSim2022\FSim_inputs\idg\PY_136_idg.tif"
# PY136 = rio.open(PY136_path)

# %%
print(PY136.meta)
# Out:
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 5648, 'height': 2753, 'count': 1, 'crs': CRS.from_epsg(3338), 'transform': Affine(270.0, 0.0, 27315.0,
#        0.0, -270.0, 1413105.0)}

# %%
# from rasterio.plot import show
# import matplotlib.pyplot as plt

# plot the IDG
plt.figure(figsize=(5,5), dpi=300)
show(PY136, title='PY136 IDG', cmap='Oranges')
# Out:
# <AxesSubplot: title={'center': 'PY136 IDG'}>
